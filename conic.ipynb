# %% [markdown]
# <a href="https://colab.research.google.com/github/kkousar/practise-/blob/main/conic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt
from math import pi

u=0    #x-position of the center
v=0    #y-position of the center
a=10.     #radius on the x-axis
b=5    #radius on the y-axis

t = np.linspace(0, 2*pi, 100)
x=np.arange(0,11,1)
y=((a*b)-(b*x))/a
plt.plot( u+a*np.cos(t) , v+b*np.sin(t) )
plt.plot(x,y,'k--')
plt.grid(color='lightgray',linestyle='--')
plt.show()
