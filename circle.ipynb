# %% [markdown]
# <a href="https://colab.research.google.com/github/kkousar/practise-/blob/main/circle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import matplotlib.pyplot as plt 

angle = np.linspace( 0 , 2 * np.pi , 150 ) ;
radius=9

x = radius * np.cos( angle ) 
y = radius * np.sin( angle ) 

plt.plot(-10,5,'ro')
plt.plot(x,y);
plt.axis([-30,30,-30,30])
plt.grid() 
plt.show()

# %%
from matplotlib import pyplot as plt, patches
plt.rcParams["figure.figsize"] = [7.00, 3.50]
#plt.rcParams["figure.autolayout"] = True
fig = plt.figure()
ax = fig.add_subplot()
circle1 = patches.Circle((0, 0), radius=2,fill = False )
circle2=patches.Circle((3,2), radius=3,fill = False )

ax.add_patch(circle1)
ax.add_patch(circle2)
plt.plot(3,2,'bo')
plt.plot(0,0,'bo')
ax.axis('equal')
plt.grid()
plt.show()

# %%
np.sqrt(91)
# Out:
# 9.539392014169456
